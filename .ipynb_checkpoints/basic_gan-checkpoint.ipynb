# %%
import os
import torch
import torchvision
import pandas as pd
import torch.nn as nn
import torch.nn.functional as F
from tqdm.notebook import tqdm
import torchvision.models as models
from torch.utils.data import Dataset
from torch.utils.data import DataLoader
from torch.utils.data import random_split
from torchvision.utils import make_grid
import torchvision.transforms as transforms
from torchvision.datasets.folder import default_loader
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Off the bat changing size of photos to 64 by 64, this could cause issues later down the road due to image sizes not being square (might modify later)

# %%
batch_size = 128
image_size = (64,64)
stats = (0.5, 0.5, 0.5), (0.5, 0.5, 0.5)

# %%
transform_ds = transforms.Compose([
                                    transforms.Resize(image_size),
#                                    transforms.RandomCrop(32, padding=2),
#                                    transforms.RandomHorizontalFlip(),
                                   transforms.ToTensor(),
                                   transforms.Normalize(*stats)
                                   ])

# %%
data_dir = 'C:\\Users\\Lucas\\haileehelp\\GAN_TEST\\A01'
train_ds = torchvision.datasets.ImageFolder(root=data_dir, 
                                            transform = transform_ds)
train_ds
# Out:
# Dataset ImageFolder
#     Number of datapoints: 4331
#     Root location: C:\Users\Lucas\haileehelp\GAN_TEST\A01
#     StandardTransform
# Transform: Compose(
#                Resize(size=(64, 64), interpolation=PIL.Image.BILINEAR)
#                ToTensor()
#                Normalize(mean=(0.5, 0.5, 0.5), std=(0.5, 0.5, 0.5))
#            )

# %%
train_dl = DataLoader(train_ds, batch_size, shuffle=True, num_workers=3, pin_memory=True)
print(len(train_ds))
# Out:
# 4331

# %%
images,_ = train_ds[5]
print(images.size())
plt.imshow(images.permute(1,2,0))
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# torch.Size([3, 64, 64])

# %%
# lets see some more

def denorm(img_tensors):
    return img_tensors * stats[1][0] + stats[0][0]
def show_images(images, nmax=64):
    fig, ax = plt.subplots(figsize=(8, 8))
    ax.set_xticks([]); ax.set_yticks([])
    ax.imshow(make_grid(denorm(images.detach()[:nmax]), nrow=8).permute(1, 2, 0))

def show_batch(dl, nmax=64):
    for images, _ in dl:
        show_images(images, nmax)
        break

show_batch(train_dl)

# %% [markdown]
# We are moving into the GAN aspect of the code.
# #### Note: using a CNN for discriminator, transposed convolution for generator

# %%
def get_default_device():
    """Pick GPU if available, else CPU"""
    if torch.cuda.is_available():
        return torch.device('cuda')
    else:
        return torch.device('cpu')
    
def to_device(data, device):
    """Move tensor(s) to chosen device"""
    if isinstance(data, (list,tuple)):
        return [to_device(x, device) for x in data]
    return data.to(device, non_blocking=True)

class DeviceDataLoader():
    """Wrap a dataloader to move data to a device"""
    def __init__(self, dl, device):
        self.dl = dl
        self.device = device
        
    def __iter__(self):
        """Yield a batch of data after moving it to device"""
        for b in self.dl: 
            yield to_device(b, self.device)

    def __len__(self):
        """Number of batches"""
        return len(self.dl)

# %%
device = get_default_device()
device
# Out:
# device(type='cpu')

# %%
train_dl = DeviceDataLoader(train_dl, device)

# %%
##creation of discriminator --look into deeper later

discriminator = nn.Sequential(
    # in: 3 x 64 x 64

    nn.Conv2d(3, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 64 x 32 x 32

    nn.Conv2d(64, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 128 x 16 x 16

    nn.Conv2d(128, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 256 x 8 x 8

    nn.Conv2d(256, 512, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(512),
    nn.LeakyReLU(0.2, inplace=True),
    # out: 512 x 4 x 4

    nn.Conv2d(512, 1, kernel_size=4, stride=1, padding=0, bias=False),
    # out: 1 x 1 x 1

    nn.Flatten(),
    nn.Sigmoid())

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.Conv2d.html

# %%
discriminator = to_device(discriminator, device)

# %%
latent_size = 150

# %%
generator = nn.Sequential(
    # in: latent_size x 1 x 1

    nn.ConvTranspose2d(latent_size, 512, kernel_size=4, stride=1, padding=0, bias=False),
    nn.BatchNorm2d(512),
    nn.ReLU(True),
    # out: 512 x 4 x 4

    nn.ConvTranspose2d(512, 256, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(256),
    nn.ReLU(True),
    # out: 256 x 8 x 8

    nn.ConvTranspose2d(256, 128, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(128),
    nn.ReLU(True),
    # out: 128 x 16 x 16

    nn.ConvTranspose2d(128, 64, kernel_size=4, stride=2, padding=1, bias=False),
    nn.BatchNorm2d(64),
    nn.ReLU(True),
    # out: 64 x 32 x 32

    nn.ConvTranspose2d(64, 3, kernel_size=4, stride=2, padding=1, bias=False),
    nn.Tanh()
    # out: 3 x 64 x 64
)

# %% [markdown]
# https://pytorch.org/docs/stable/generated/torch.nn.ConvTranspose2d.html

# %%
xb = torch.randn(batch_size, latent_size, 1, 1) # random latent tensors
fake_images = generator(xb)
print(fake_images.shape)
show_images(fake_images)
# Out:
# torch.Size([128, 3, 64, 64])

# %%
generator = to_device(generator, device)

# %%
def train_discriminator(real_images, opt_d):
    # Clear discriminator gradients
    opt_d.zero_grad()

    # Pass real images through discriminator
    real_preds = discriminator(real_images)
    real_targets = torch.ones(real_images.size(0), 1, device=device)
    real_loss = F.binary_cross_entropy(real_preds, real_targets)
    real_score = torch.mean(real_preds).item()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)

    # Pass fake images through discriminator
    fake_targets = torch.zeros(fake_images.size(0), 1, device=device)
    fake_preds = discriminator(fake_images)
    fake_loss = F.binary_cross_entropy(fake_preds, fake_targets)
    fake_score = torch.mean(fake_preds).item()

    # Update discriminator weights
    loss = real_loss + fake_loss
    loss.backward()
    opt_d.step()
    return loss.item(), real_score, fake_score

# %%
def train_generator(opt_g):
    # Clear generator gradients
    opt_g.zero_grad()
    
    # Generate fake images
    latent = torch.randn(batch_size, latent_size, 1, 1, device=device)
    fake_images = generator(latent)
    
    # Try to fool the discriminator
    preds = discriminator(fake_images)
    targets = torch.ones(batch_size, 1, device=device)
    loss = F.binary_cross_entropy(preds, targets)
    
    # Update generator weights
    loss.backward()
    opt_g.step()
    
    return loss.item()

# %%
from torchvision.utils import save_image

# %%
sample_dir = 'GAN_TESTING'
os.makedirs(sample_dir, exist_ok=True)

# %%
def save_samples(index, latent_tensors, show=True):
    fake_images = generator(latent_tensors)
    fake_fname = 'generated-images-{0:0=4d}.png'.format(index)
    save_image(denorm(fake_images), os.path.join(sample_dir, fake_fname), nrow=8)
    print('Saving', fake_fname)
    if show:
        fig, ax = plt.subplots(figsize=(8, 8))
        ax.set_xticks([]); ax.set_yticks([])
        ax.imshow(make_grid(fake_images.cpu().detach(), nrow=8).permute(1, 2, 0))

# %%
fixed_latent = torch.randn(64, latent_size, 1, 1, device=device)

# %%
save_samples(0, fixed_latent) # saved inside A01/archive/GAN_TESTING
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# Saving generated-images-0000.png

# %%
from tqdm.notebook import tqdm
import torch.nn.functional as F

# %%
def fit(epochs, lr, start_idx=1):
    #torch.cuda.empty_cache()
    
    # Losses & scores
    losses_g = []
    losses_d = []
    real_scores = []
    fake_scores = []
    
    # Create optimizers
    #you can use diff learning rates if you want
    opt_d = torch.optim.Adam(discriminator.parameters(), lr=lr, betas=(0.5, 0.999))
    opt_g = torch.optim.Adam(generator.parameters(), lr=lr, betas=(0.5, 0.999))
    
    for epoch in range(epochs):
        for real_images, _ in tqdm(train_dl):
            # Train discriminator
            loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
            # Train generator
            loss_g = train_generator(opt_g)
            
        # Record losses & scores
        losses_g.append(loss_g)
        losses_d.append(loss_d)
        real_scores.append(real_score)
        fake_scores.append(fake_score)
        
        # Log losses & scores (last batch)
        print("Epoch [{}/{}], loss_g: {:.4f}, loss_d: {:.4f}, real_score: {:.4f}, fake_score: {:.4f}".format(
            epoch+1, epochs, loss_g, loss_d, real_score, fake_score))
    
        # Save generated images
        save_samples(epoch+start_idx, fixed_latent, show=False)
    
    return losses_g, losses_d, real_scores, fake_scores

# %%
lr = 0.001
epochs = 150

# %%
history = fit(epochs,lr)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [1/150], loss_g: 2.9304, loss_d: 0.2518, real_score: 0.8762, fake_score: 0.0789
# Saving generated-images-0001.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [2/150], loss_g: 3.8353, loss_d: 1.3952, real_score: 0.3449, fake_score: 0.0121
# Saving generated-images-0002.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [3/150], loss_g: 1.5235, loss_d: 2.6627, real_score: 0.1155, fake_score: 0.0530
# Saving generated-images-0003.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [4/150], loss_g: 1.5482, loss_d: 0.7290, real_score: 0.6028, fake_score: 0.1372
# Saving generated-images-0004.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [5/150], loss_g: 2.1047, loss_d: 1.2938, real_score: 0.7346, fake_score: 0.5750
# Saving generated-images-0005.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [6/150], loss_g: 2.4331, loss_d: 0.6552, real_score: 0.7577, fake_score: 0.2666
# Saving generated-images-0006.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [7/150], loss_g: 3.7294, loss_d: 1.8702, real_score: 0.8336, fake_score: 0.7052
# Saving generated-images-0007.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [8/150], loss_g: 1.1901, loss_d: 1.1377, real_score: 0.4641, fake_score: 0.2059
# Saving generated-images-0008.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [9/150], loss_g: 2.7553, loss_d: 1.2076, real_score: 0.7394, fake_score: 0.5303
# Saving generated-images-0009.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [10/150], loss_g: 2.8516, loss_d: 1.2007, real_score: 0.6689, fake_score: 0.5129
# Saving generated-images-0010.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [11/150], loss_g: 2.4621, loss_d: 0.9722, real_score: 0.6655, fake_score: 0.3744
# Saving generated-images-0011.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [12/150], loss_g: 2.1468, loss_d: 1.1406, real_score: 0.6679, fake_score: 0.4913
# Saving generated-images-0012.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [13/150], loss_g: 2.7323, loss_d: 1.2259, real_score: 0.7658, fake_score: 0.5622
# Saving generated-images-0013.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [14/150], loss_g: 2.7440, loss_d: 1.3343, real_score: 0.8509, fake_score: 0.6370
# Saving generated-images-0014.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [15/150], loss_g: 3.3590, loss_d: 1.2901, real_score: 0.7723, fake_score: 0.6058
# Saving generated-images-0015.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [16/150], loss_g: 1.8473, loss_d: 1.5130, real_score: 0.3167, fake_score: 0.0639
# Saving generated-images-0016.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [17/150], loss_g: 2.1764, loss_d: 0.8790, real_score: 0.7738, fake_score: 0.4139
# Saving generated-images-0017.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [18/150], loss_g: 3.2915, loss_d: 1.0617, real_score: 0.9179, fake_score: 0.5952
# Saving generated-images-0018.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [19/150], loss_g: 1.0012, loss_d: 1.2348, real_score: 0.4411, fake_score: 0.2149
# Saving generated-images-0019.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [20/150], loss_g: 1.1059, loss_d: 0.9530, real_score: 0.5154, fake_score: 0.1792
# Saving generated-images-0020.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [21/150], loss_g: 3.7902, loss_d: 1.4301, real_score: 0.6967, fake_score: 0.6048
# Saving generated-images-0021.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [22/150], loss_g: 3.5237, loss_d: 1.1925, real_score: 0.8369, fake_score: 0.5770
# Saving generated-images-0022.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [23/150], loss_g: 1.5809, loss_d: 1.3166, real_score: 0.3781, fake_score: 0.1556
# Saving generated-images-0023.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [24/150], loss_g: 1.8873, loss_d: 1.6994, real_score: 0.5866, fake_score: 0.6097
# Saving generated-images-0024.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [25/150], loss_g: 1.9061, loss_d: 0.8900, real_score: 0.6666, fake_score: 0.3099
# Saving generated-images-0025.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [26/150], loss_g: 2.9561, loss_d: 1.1995, real_score: 0.5830, fake_score: 0.3979
# Saving generated-images-0026.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [27/150], loss_g: 1.9575, loss_d: 0.6415, real_score: 0.8258, fake_score: 0.3364
# Saving generated-images-0027.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [28/150], loss_g: 2.2345, loss_d: 1.1168, real_score: 0.5609, fake_score: 0.3032
# Saving generated-images-0028.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [29/150], loss_g: 2.7371, loss_d: 1.4985, real_score: 0.3316, fake_score: 0.0201
# Saving generated-images-0029.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [30/150], loss_g: 3.3550, loss_d: 1.4906, real_score: 0.8120, fake_score: 0.6272
# Saving generated-images-0030.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [31/150], loss_g: 3.4831, loss_d: 0.9754, real_score: 0.8110, fake_score: 0.4634
# Saving generated-images-0031.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [32/150], loss_g: 3.2829, loss_d: 0.6435, real_score: 0.6942, fake_score: 0.1618
# Saving generated-images-0032.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [33/150], loss_g: 3.2679, loss_d: 0.6218, real_score: 0.7770, fake_score: 0.2756
# Saving generated-images-0033.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [34/150], loss_g: 3.2431, loss_d: 1.0047, real_score: 0.7862, fake_score: 0.4748
# Saving generated-images-0034.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [35/150], loss_g: 4.5349, loss_d: 0.9196, real_score: 0.9073, fake_score: 0.5229
# Saving generated-images-0035.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [36/150], loss_g: 4.1242, loss_d: 1.1346, real_score: 0.9317, fake_score: 0.5823
# Saving generated-images-0036.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [37/150], loss_g: 4.7658, loss_d: 0.9675, real_score: 0.8815, fake_score: 0.5100
# Saving generated-images-0037.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [38/150], loss_g: 2.8875, loss_d: 0.8268, real_score: 0.7117, fake_score: 0.3037
# Saving generated-images-0038.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [39/150], loss_g: 3.9042, loss_d: 0.3835, real_score: 0.8313, fake_score: 0.1480
# Saving generated-images-0039.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [40/150], loss_g: 3.3767, loss_d: 0.6879, real_score: 0.8290, fake_score: 0.3288
# Saving generated-images-0040.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [41/150], loss_g: 4.9325, loss_d: 0.6719, real_score: 0.9126, fake_score: 0.3750
# Saving generated-images-0041.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [42/150], loss_g: 3.7074, loss_d: 0.8033, real_score: 0.8150, fake_score: 0.3610
# Saving generated-images-0042.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [43/150], loss_g: 3.4610, loss_d: 0.5510, real_score: 0.7292, fake_score: 0.1486
# Saving generated-images-0043.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [44/150], loss_g: 5.6125, loss_d: 1.2109, real_score: 0.8621, fake_score: 0.5748
# Saving generated-images-0044.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [45/150], loss_g: 4.2514, loss_d: 1.3072, real_score: 0.8776, fake_score: 0.5908
# Saving generated-images-0045.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [46/150], loss_g: 2.1428, loss_d: 1.2936, real_score: 0.3799, fake_score: 0.0596
# Saving generated-images-0046.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [47/150], loss_g: 0.9205, loss_d: 1.7559, real_score: 0.2708, fake_score: 0.0245
# Saving generated-images-0047.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [48/150], loss_g: 5.3038, loss_d: 0.8579, real_score: 0.8585, fake_score: 0.4608
# Saving generated-images-0048.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [49/150], loss_g: 1.4237, loss_d: 1.5024, real_score: 0.3719, fake_score: 0.1267
# Saving generated-images-0049.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [50/150], loss_g: 2.5273, loss_d: 0.6290, real_score: 0.8142, fake_score: 0.2203
# Saving generated-images-0050.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [51/150], loss_g: 4.9664, loss_d: 0.6722, real_score: 0.9179, fake_score: 0.3626
# Saving generated-images-0051.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [52/150], loss_g: 1.5631, loss_d: 0.6820, real_score: 0.6483, fake_score: 0.1410
# Saving generated-images-0052.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [53/150], loss_g: 4.6160, loss_d: 1.0200, real_score: 0.7879, fake_score: 0.4688
# Saving generated-images-0053.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [54/150], loss_g: 4.2578, loss_d: 1.3654, real_score: 0.9661, fake_score: 0.6612
# Saving generated-images-0054.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [55/150], loss_g: 3.6996, loss_d: 0.6658, real_score: 0.8876, fake_score: 0.3458
# Saving generated-images-0055.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [56/150], loss_g: 1.9012, loss_d: 0.8388, real_score: 0.5692, fake_score: 0.0766
# Saving generated-images-0056.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [57/150], loss_g: 5.6163, loss_d: 1.2299, real_score: 0.9043, fake_score: 0.6215
# Saving generated-images-0057.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [58/150], loss_g: 2.1531, loss_d: 0.8691, real_score: 0.6363, fake_score: 0.2322
# Saving generated-images-0058.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [59/150], loss_g: 3.7508, loss_d: 0.5779, real_score: 0.6365, fake_score: 0.0337
# Saving generated-images-0059.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [60/150], loss_g: 4.0381, loss_d: 0.7373, real_score: 0.8452, fake_score: 0.3477
# Saving generated-images-0060.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [61/150], loss_g: 2.2339, loss_d: 0.8768, real_score: 0.5471, fake_score: 0.1378
# Saving generated-images-0061.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [62/150], loss_g: 0.8469, loss_d: 1.6198, real_score: 0.2807, fake_score: 0.0123
# Saving generated-images-0062.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [63/150], loss_g: 4.0088, loss_d: 0.7055, real_score: 0.6851, fake_score: 0.2120
# Saving generated-images-0063.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [64/150], loss_g: 3.2456, loss_d: 0.4038, real_score: 0.8343, fake_score: 0.1525
# Saving generated-images-0064.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [65/150], loss_g: 4.7518, loss_d: 1.0964, real_score: 0.8347, fake_score: 0.4978
# Saving generated-images-0065.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [66/150], loss_g: 3.0399, loss_d: 0.6142, real_score: 0.8782, fake_score: 0.3327
# Saving generated-images-0066.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [67/150], loss_g: 2.3804, loss_d: 0.7192, real_score: 0.6110, fake_score: 0.0945
# Saving generated-images-0067.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [68/150], loss_g: 1.5179, loss_d: 0.7563, real_score: 0.6214, fake_score: 0.1570
# Saving generated-images-0068.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [69/150], loss_g: 3.6459, loss_d: 0.4882, real_score: 0.8787, fake_score: 0.2606
# Saving generated-images-0069.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [70/150], loss_g: 3.1793, loss_d: 0.5639, real_score: 0.6711, fake_score: 0.0691
# Saving generated-images-0070.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [71/150], loss_g: 3.6038, loss_d: 0.3322, real_score: 0.8438, fake_score: 0.1081
# Saving generated-images-0071.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [72/150], loss_g: 1.8657, loss_d: 0.7708, real_score: 0.6256, fake_score: 0.1144
# Saving generated-images-0072.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [73/150], loss_g: 5.8426, loss_d: 0.5108, real_score: 0.9521, fake_score: 0.3240
# Saving generated-images-0073.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [74/150], loss_g: 2.8856, loss_d: 0.4775, real_score: 0.7821, fake_score: 0.1515
# Saving generated-images-0074.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [75/150], loss_g: 1.7161, loss_d: 0.8335, real_score: 0.6612, fake_score: 0.2402
# Saving generated-images-0075.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [76/150], loss_g: 6.1752, loss_d: 1.0721, real_score: 0.8949, fake_score: 0.4932
# Saving generated-images-0076.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [77/150], loss_g: 3.8553, loss_d: 0.3563, real_score: 0.8284, fake_score: 0.1181
# Saving generated-images-0077.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [78/150], loss_g: 3.5736, loss_d: 0.4269, real_score: 0.8183, fake_score: 0.1666
# Saving generated-images-0078.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# Epoch [79/150], loss_g: 2.4786, loss_d: 0.4459, real_score: 0.7728, fake_score: 0.1167
# Saving generated-images-0079.png
# HBox(children=(FloatProgress(value=0.0, max=34.0), HTML(value='')))
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-27-2f3170a493d1> in <module>
# ----> 1 history = fit(epochs,lr)
#
# <ipython-input-25-6945ceae0949> in fit(epochs, lr, start_idx)
#      14
#      15     for epoch in range(epochs):
# ---> 16         for real_images, _ in tqdm(train_dl):
#      17             # Train discriminator
#      18             loss_d, real_score, fake_score = train_discriminator(real_images, opt_d)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tqdm/notebook.py in __iter__(self, *args, **kwargs)
#     215     def __iter__(self, *args, **kwargs):
#     216         try:
# --> 217             for obj in super(tqdm_notebook, self).__iter__(*args, **kwargs):
#     218                 # return super(tqdm...) will not catch exception
#     219                 yield obj
#
# ~/opt/anaconda3/lib/python3.8/site-packages/tqdm/std.py in __iter__(self)
#    1127
#    1128         try:
# -> 1129             for obj in iterable:
#    1130                 yield obj
#    1131                 # Update and possibly print the progressbar.
#
# <ipython-input-8-24f54f5041f7> in __iter__(self)
#      20     def __iter__(self):
#      21         """Yield a batch of data after moving it to device"""
# ---> 22         for b in self.dl:
#      23             yield to_device(b, self.device)
#      24
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in __next__(self)
#     433         if self._sampler_iter is None:
#     434             self._reset()
# --> 435         data = self._next_data()
#     436         self._num_yielded += 1
#     437         if self._dataset_kind == _DatasetKind.Iterable and \
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _next_data(self)
#    1083             else:
#    1084                 del self._task_info[idx]
# -> 1085                 return self._process_data(data)
#    1086
#    1087     def _try_put_index(self):
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/dataloader.py in _process_data(self, data)
#    1109         self._try_put_index()
#    1110         if isinstance(data, ExceptionWrapper):
# -> 1111             data.reraise()
#    1112         return data
#    1113
#
# ~/opt/anaconda3/lib/python3.8/site-packages/torch/_utils.py in reraise(self)
#     426             # have message field
#     427             raise self.exc_type(message=msg)
# --> 428         raise self.exc_type(msg)
#     429
#     430
#
# RuntimeError: Caught RuntimeError in DataLoader worker process 2.
# Original Traceback (most recent call last):
#   File "/Users/haileekiesecker/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/worker.py", line 198, in _worker_loop
#     data = fetcher.fetch(index)
#   File "/Users/haileekiesecker/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/fetch.py", line 47, in fetch
#   File "/Users/haileekiesecker/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py", line 83, in default_collate
#   File "/Users/haileekiesecker/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py", line 83, in <listcomp>
#   File "/Users/haileekiesecker/opt/anaconda3/lib/python3.8/site-packages/torch/utils/data/_utils/collate.py", line 53, in default_collate
#   File "/Users/haileekiesecker/opt/anaconda3/lib/python3.8/site-packages/torch/storage.py", line 135, in _new_shared
# RuntimeError: Other end has closed the connection at /Users/distiller/project/conda/conda-bld/pytorch_1607370249289/work/torch/lib/libshm/core.cpp:99
